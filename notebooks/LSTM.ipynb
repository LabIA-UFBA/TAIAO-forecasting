# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    median_absolute_error,
    explained_variance_score,
    mean_absolute_percentage_error
)

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=32, num_layers=1, output_dim=1):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, output_dim)

    def forward(self, x):
        out, _ = self.lstm(x)             
        out = self.linear(out[:, -1, :])  # pegar o último passo da sequência
        return out

# %%
# Parâmetros
window_size = 100  # tamanho do meu X
hidden_size = 64   # Camadas ocultas
n_steps=100        # horizonte de previsão
epochs = 1000       # number of epochs
lr = 0.001         # learning rate

# %%
df = pd.read_parquet("../dataset_temperature_c_interpolation.parquet")
df.head()
# Out:
#                 time  Napier_Aerodrome  Wellington_Aerodrome  Enderby_Island  \
# 0  01-Apr-1993 00:00              15.0                  17.0             7.0
# 1  01-Apr-1993 01:00              14.0                  17.0             7.0
# 2  01-Apr-1993 02:00              14.0                  17.0             7.0
# 3  01-Apr-1993 03:00              13.0                  17.0             7.0
# 4  01-Apr-1993 04:00              13.0                  17.0             7.0
#
#    Mokohinau_Island  Cape_Campbell  Westport_Aerodrome  Mahia_NZMHX  \
# 0              17.0           11.0                17.0         14.0
# 1              17.0           11.0                16.0         14.0
# 2              17.0           11.0                16.0         15.0
# 3              17.0           11.0                16.0         15.0
# 4              17.0           11.0                15.0         15.0
#
#    Nelson_Aerodrome  Queenstown_Aerodrome  ...  Port_Taharoa  Palmerston_N  \
# 0              15.0                   8.0  ...          15.0          14.0
# 1              15.0                   8.0  ...          14.0          15.0
# 2              15.0                   7.0  ...          14.0          14.0
# 3              14.0                   6.0  ...          15.0          14.0
# 4              14.0                   7.0  ...          15.0          14.0
#
#    Gisborne_Aerodrome  Nugget_Point  Dunedin_Aerodrome  Cape_Reinga  \
# 0                16.0          10.0                8.0         17.0
# 1                15.0          10.0                8.0         16.0
# 2                15.0          10.0                8.0         16.0
# 3                14.0          10.0                8.0         16.0
# 4                14.0          10.0                8.0         16.0
#
#    Secretary_Island  Kaitaia_Aerodrome  Takapau_Plains  split
# 0              14.0               16.5            11.4   True
# 1              14.0               16.5            11.4   True
# 2              14.0               16.5            11.4   True
# 3              14.0               16.5            11.4   True
# 4              14.0               16.5            11.4   True
#
# [5 rows x 53 columns]

# %%
station = "Napier_Aerodrome"

# %%
train_data = df.query("split == True")[station].values[-1000:]
test_data  = df.query(" split == False ")[station].values[:500]
train_data.shape, test_data.shape
# Out:
# ((1000,), (500,))

# %%
def create_dataset(series, window_size, horizon):
    """
    Gera X e y para previsão de múltiplos passos.

    Args:
        series (array-like): sequência de valores.
        window_size (int): tamanho da janela de entrada.
        horizon (int): número de passos à frente a prever.

    Returns:
        X: Tensor de forma (n_amostras, window_size)
        y: Tensor de forma (n_amostras, horizon)
    """
    X, y = [], []
    max_start = len(series) - window_size - horizon + 1
    for i in range(max_start):
        X.append(series[i : i + window_size])
        y.append(series[i + window_size : i + window_size + horizon])
        
    X = torch.tensor(X, dtype=torch.float32)
    y = torch.tensor(y, dtype=torch.float32)

    return X, y

# %%
X_train, y_train = create_dataset(train_data, window_size, n_steps)
X_test, y_test = create_dataset(test_data, window_size, n_steps)
# Out:
# /tmp/ipykernel_2608364/35059170.py:20: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:261.)
#   X = torch.tensor(X, dtype=torch.float32)

# %%
X_train = X_train.unsqueeze(-1)
X_test  = X_test.unsqueeze(-1)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %%
# Modelo
model = LSTMModel(input_size=window_size, 
                  hidden_size=hidden_size, 
                  num_layers=2, 
                  output_dim=n_steps)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

# %%
# Loop de treino
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()
    output = model(X_train)
    loss = criterion(output, y_train)
    loss.backward()
    optimizer.step()
    if epoch % 10 == 0:
        print(f"Epoch {epoch} - Loss: {loss.item():.4f}")
# Out:
# Epoch 0 - Loss: 337.1654
# Epoch 10 - Loss: 329.1211
# Epoch 20 - Loss: 303.7686
# Epoch 30 - Loss: 272.4359
# Epoch 40 - Loss: 244.4428
# Epoch 50 - Loss: 220.0011
# Epoch 60 - Loss: 198.0754
# Epoch 70 - Loss: 178.7025
# Epoch 80 - Loss: 161.4247
# Epoch 90 - Loss: 145.9351
# Epoch 100 - Loss: 131.9996
# Epoch 110 - Loss: 119.4335
# Epoch 120 - Loss: 108.0892
# Epoch 130 - Loss: 97.8453
# Epoch 140 - Loss: 88.5992
# Epoch 150 - Loss: 80.2618
# Epoch 160 - Loss: 72.7545
# Epoch 170 - Loss: 66.0062
# Epoch 180 - Loss: 59.9521
# Epoch 190 - Loss: 54.5328
# Epoch 200 - Loss: 49.6932
# Epoch 210 - Loss: 45.3820
# Epoch 220 - Loss: 41.5518
# Epoch 230 - Loss: 38.1581
# Epoch 240 - Loss: 35.1597
# Epoch 250 - Loss: 32.5183
# Epoch 260 - Loss: 30.1983
# Epoch 270 - Loss: 28.1668
# Epoch 280 - Loss: 26.3935
# Epoch 290 - Loss: 24.8503
# Epoch 300 - Loss: 23.5116
# Epoch 310 - Loss: 22.3542
# Epoch 320 - Loss: 21.3566
# Epoch 330 - Loss: 20.4996
# Epoch 340 - Loss: 19.7658
# Epoch 350 - Loss: 19.1396
# Epoch 360 - Loss: 18.6069
# Epoch 370 - Loss: 18.1553
# Epoch 380 - Loss: 17.7737
# Epoch 390 - Loss: 17.4523
# Epoch 400 - Loss: 17.1826
# Epoch 410 - Loss: 16.9569
# Epoch 420 - Loss: 16.7687
# Epoch 430 - Loss: 16.6123
# Epoch 440 - Loss: 16.4827
# Epoch 450 - Loss: 16.3758
# Epoch 460 - Loss: 16.2877
# Epoch 470 - Loss: 16.2155
# Epoch 480 - Loss: 16.1565
# Epoch 490 - Loss: 16.1084
# Epoch 500 - Loss: 16.0694
# Epoch 510 - Loss: 16.0378
# Epoch 520 - Loss: 16.0123
# Epoch 530 - Loss: 15.9917
# Epoch 540 - Loss: 15.9753
# Epoch 550 - Loss: 15.9622
# Epoch 560 - Loss: 15.9517
# Epoch 570 - Loss: 15.9434
# Epoch 580 - Loss: 15.9368
# Epoch 590 - Loss: 15.9316
# Epoch 600 - Loss: 15.9275
# Epoch 610 - Loss: 15.9243
# Epoch 620 - Loss: 15.9218
# Epoch 630 - Loss: 15.9199
# Epoch 640 - Loss: 15.9184
# Epoch 650 - Loss: 15.9172
# Epoch 660 - Loss: 15.9163
# Epoch 670 - Loss: 15.9156
# Epoch 680 - Loss: 15.9151
# Epoch 690 - Loss: 15.9147
# Epoch 700 - Loss: 15.9144
# Epoch 710 - Loss: 15.9142
# Epoch 720 - Loss: 15.9140
# Epoch 730 - Loss: 15.9138
# Epoch 740 - Loss: 15.9137
# Epoch 750 - Loss: 15.9137
# Epoch 760 - Loss: 15.9136
# Epoch 770 - Loss: 15.9136
# Epoch 780 - Loss: 15.9135
# Epoch 790 - Loss: 15.9135
# Epoch 800 - Loss: 15.9135
# Epoch 810 - Loss: 15.9135
# Epoch 820 - Loss: 15.9135
# Epoch 830 - Loss: 15.9135
# Epoch 840 - Loss: 15.9135
# Epoch 850 - Loss: 15.9135
# Epoch 860 - Loss: 15.9135
# Epoch 870 - Loss: 15.9135
# Epoch 880 - Loss: 15.9135
# Epoch 890 - Loss: 15.9135
# Epoch 900 - Loss: 15.9135
# Epoch 910 - Loss: 15.9135
# Epoch 920 - Loss: 15.9135
# Epoch 930 - Loss: 15.9135
# Epoch 940 - Loss: 15.9135
# Epoch 950 - Loss: 15.9135
# Epoch 960 - Loss: 15.9135
# Epoch 970 - Loss: 15.9135
# Epoch 980 - Loss: 15.9135
# Epoch 990 - Loss: 15.9135

# %%
model.eval()
with torch.no_grad():
    preds = model(X_test)
    test_loss = criterion(preds, y_test)
    print(f"Test Loss: {test_loss.item():.4f}")
# Out:
# Test Loss: 12.2094

# %%
plt.plot(np.arange(100, 200), y_test.cpu().numpy()[0,:], label="Out test")

plt.legend()
plt.title("LSTM Forecast")
plt.show()

# %%
idx = 0

ytrues = []
ypreds = []

for i in range(3):
    
    y_true = y_test[idx,:].cpu().numpy().tolist()
    y_pred = preds[idx,:].cpu().numpy().tolist()
    
    ytrues.extend(y_true)
    ypreds.extend(y_pred)
    
    idx += 100

# %%
## create dataframe to save results
plt.figure(figsize=(16, 4))
plt.plot(np.arange(0, 100), test_data[0:100], label="Input Real Data ")
plt.plot(np.arange(100, len(ytrues)+100), ytrues, label="Ground Truth")
plt.plot(np.arange(100, len(ypreds)+100), ypreds, label="SARIMA Forecasting")
plt.legend()
plt.show()

# %%
from val import regression_metrics
metrics = regression_metrics(ytrues, ypreds)
metrics
# Out:
# {'DTW': 847.4753198623657,
#  'MAE': 2.8518079408009847,
#  'MSE': 14.031058279376348,
#  'RMSE': 3.7458054246552033,
#  'MAPE': 14.828142280474117,
#  'R2': -0.10961746084539237}
